# %%
import tensorflow as tf
import numpy as np
import time
import os
from sklearn.preprocessing import LabelEncoder
import re
import collections
import random
import pickle

# %%
maxlen = 20
location = os.getcwd()
num_layers = 3
size_layer = 256
learning_rate = 0.00001
batch = 100

# %%
with open('dataset-emotion.p', 'rb') as fopen:
    df = pickle.load(fopen)
with open('vector-emotion.p', 'rb') as fopen:
    vectors = pickle.load(fopen)
with open('dataset-dictionary.p', 'rb') as fopen:
    dictionary = pickle.load(fopen)

# %%
label = np.unique(df[:,1])

# %%
from sklearn.cross_validation import train_test_split
train_X, test_X, train_Y, test_Y = train_test_split(df[:,0], df[:, 1].astype('int'), test_size = 0.2)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
class Model:
    
    def __init__(self, num_layers, size_layer, dimension_input, dimension_output, learning_rate):
        def lstm_cell():
            return tf.nn.rnn_cell.LSTMCell(size_layer)
        self.X = tf.placeholder(tf.float32, [None, None, dimension_input])
        self.Y = tf.placeholder(tf.float32, [None, dimension_output])
        
        with tf.variable_scope("hinge", reuse = False):
            rnn_cells_hinge = tf.nn.rnn_cell.MultiRNNCell([lstm_cell() for _ in range(num_layers)])
            drop_hinge = tf.contrib.rnn.DropoutWrapper(rnn_cells_hinge, output_keep_prob = 0.5)
            self.outputs_hinge, _ = tf.nn.dynamic_rnn(drop_hinge, self.X, dtype = tf.float32)
            rnn_W_hinge = tf.Variable(tf.random_normal((size_layer, dimension_output)))
            rnn_B_hinge = tf.Variable(tf.random_normal([dimension_output]))
            self.logits_hinge = tf.matmul(self.outputs_hinge[:, -1], rnn_W_hinge) + rnn_B_hinge
        
        with tf.variable_scope("huber", reuse = False):
            rnn_cells_huber = tf.nn.rnn_cell.MultiRNNCell([lstm_cell() for _ in range(num_layers)])
            drop_huber = tf.contrib.rnn.DropoutWrapper(rnn_cells_huber, output_keep_prob = 0.5)
            self.outputs_huber, _ = tf.nn.dynamic_rnn(drop_huber, self.X, dtype = tf.float32)
            rnn_W_huber = tf.Variable(tf.random_normal((size_layer, dimension_output)))
            rnn_B_huber = tf.Variable(tf.random_normal([dimension_output]))
            self.logits_huber = tf.matmul(self.outputs_huber[:, -1], rnn_W_huber) + rnn_B_huber
            
        rnn_W = tf.Variable(tf.random_normal((dimension_output * 2, dimension_output)))
        rnn_B = tf.Variable(tf.random_normal([dimension_output]))
        self.logits = tf.matmul(tf.concat([self.logits_hinge,self.logits_huber],1), rnn_W) + rnn_B
        
        cost_hinge = tf.losses.hinge_loss(logits = self.logits_hinge, labels = self.Y)
        cost_huber = tf.losses.huber_loss(predictions = self.logits_huber, labels = self.Y)
        cost_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = self.logits, labels = self.Y))
        self.cost = 0.5 * cost_entropy + 0.25 * cost_huber + 0.25 * cost_hinge
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        self.correct_pred = tf.equal(tf.argmax(self.logits, 1), tf.argmax(self.Y, 1))
        self.accuracy = tf.reduce_mean(tf.cast(self.correct_pred, tf.float32))

# %%
tf.reset_default_graph()
sess = tf.InteractiveSession()
model = Model(num_layers, size_layer, vectors.shape[1], label.shape[0], learning_rate)
sess.run(tf.global_variables_initializer())
dimension = vectors.shape[1]
saver = tf.train.Saver(tf.global_variables())
EARLY_STOPPING, CURRENT_CHECKPOINT, CURRENT_ACC, EPOCH = 10, 0, 0, 0
while True:
    lasttime = time.time()
    if CURRENT_CHECKPOINT == EARLY_STOPPING:
        print('break epoch:', EPOCH)
        break
    train_acc, train_loss, test_acc, test_loss = 0, 0, 0, 0
    for i in range(0, (train_X.shape[0] // batch) * batch, batch):
        batch_x = np.zeros((batch, maxlen, dimension))
        batch_y = np.zeros((batch, len(label)))
        for k in range(batch):
            tokens = train_X[i + k].split()[:maxlen]
            emb_data = np.zeros((maxlen, dimension), dtype = np.float32)
            for no, text in enumerate(tokens[::-1]):
                try:
                    emb_data[-1 - no, :] += vectors[dictionary[text], :]
                except Exception as e:
                    print(e)
                    continue
            batch_y[k, int(train_Y[i + k])] = 1.0
            batch_x[k, :, :] = emb_data[:, :]
        loss, _ = sess.run([model.cost, model.optimizer], feed_dict = {model.X : batch_x, model.Y : batch_y})
        train_loss += loss
        train_acc += sess.run(model.accuracy, feed_dict = {model.X : batch_x, model.Y : batch_y})
    
    for i in range(0, (test_X.shape[0] // batch) * batch, batch):
        batch_x = np.zeros((batch, maxlen, dimension))
        batch_y = np.zeros((batch, len(label)))
        for k in range(batch):
            tokens = test_X[i + k].split()[:maxlen]
            emb_data = np.zeros((maxlen, dimension), dtype = np.float32)
            for no, text in enumerate(tokens[::-1]):
                try:
                    emb_data[-1 - no, :] += vectors[dictionary[text], :]
                except:
                    continue
            batch_y[k, int(test_Y[i + k])] = 1.0
            batch_x[k, :, :] = emb_data[:, :]
        loss, acc = sess.run([model.cost, model.accuracy], feed_dict = {model.X : batch_x, model.Y : batch_y})
        test_loss += loss
        test_acc += acc
        
    train_loss /= (train_X.shape[0] // batch)
    train_acc /= (train_X.shape[0] // batch)
    test_loss /= (test_X.shape[0] // batch)
    test_acc /= (test_X.shape[0] // batch)
    if test_acc > CURRENT_ACC:
        print('epoch:', EPOCH, ', pass acc:', CURRENT_ACC, ', current acc:', test_acc)
        CURRENT_ACC = test_acc
        CURRENT_CHECKPOINT = 0
        saver.save(sess, os.getcwd() + "/model-rnn-vector-huber.ckpt")
    else:
        CURRENT_CHECKPOINT += 1
    EPOCH += 1
    print('time taken:', time.time()-lasttime)
    print('epoch:', EPOCH, ', training loss:', train_loss, ', training acc:', train_acc, ', valid loss:', test_loss, ', valid acc:', test_acc)
# Out:
# 'unwarrentedly'
# epoch: 0 , pass acc: 0 , current acc: 0.478139239378
# time taken: 385.6946692466736
# epoch: 1 , training loss: 1.05275394967 , training acc: 0.395353915734 , valid loss: 0.888166211304 , valid acc: 0.478139239378
# 'unwarrentedly'
# epoch: 1 , pass acc: 0.478139239378 , current acc: 0.535894331561
# time taken: 387.14651441574097
# epoch: 2 , training loss: 0.851500043951 , training acc: 0.512057565363 , valid loss: 0.824780380669 , valid acc: 0.535894331561
# 'unwarrentedly'
# epoch: 2 , pass acc: 0.535894331561 , current acc: 0.562665036997
# time taken: 387.8405590057373
# epoch: 3 , training loss: 0.804589801909 , training acc: 0.551400691342 , valid loss: 0.788741553102 , valid acc: 0.562665036997
# 'unwarrentedly'
# epoch: 3 , pass acc: 0.562665036997 , current acc: 0.58507800782
# time taken: 387.46556520462036
# epoch: 4 , training loss: 0.772734787358 , training acc: 0.575671835071 , valid loss: 0.760341488871 , valid acc: 0.58507800782
# 'unwarrentedly'
# epoch: 4 , pass acc: 0.58507800782 , current acc: 0.602124820809
# time taken: 387.42529821395874
# epoch: 5 , training loss: 0.746228005815 , training acc: 0.595347900598 , valid loss: 0.735962200923 , valid acc: 0.602124820809
# 'unwarrentedly'
# epoch: 5 , pass acc: 0.602124820809 , current acc: 0.618679443685
# time taken: 387.61539936065674
# epoch: 6 , training loss: 0.721990106935 , training acc: 0.612357499414 , valid loss: 0.71186191416 , valid acc: 0.618679443685
# 'unwarrentedly'
# epoch: 6 , pass acc: 0.618679443685 , current acc: 0.633265275557
# time taken: 387.46066069602966
# epoch: 7 , training loss: 0.697996535073 , training acc: 0.629358099261 , valid loss: 0.688268042126 , valid acc: 0.633265275557
# 'unwarrentedly'
# epoch: 7 , pass acc: 0.633265275557 , current acc: 0.64773106253
# time taken: 387.35986256599426
# epoch: 8 , training loss: 0.675451798466 , training acc: 0.643290312645 , valid loss: 0.66829936108 , valid acc: 0.64773106253
# 'unwarrentedly'
# epoch: 8 , pass acc: 0.64773106253 , current acc: 0.659603818875
# time taken: 387.3392472267151
# epoch: 9 , training loss: 0.653644726387 , training acc: 0.657804410438 , valid loss: 0.64824546006 , valid acc: 0.659603818875
# 'unwarrentedly'
# epoch: 9 , pass acc: 0.659603818875 , current acc: 0.673781491414
# time taken: 387.4636011123657
# epoch: 10 , training loss: 0.633108772467 , training acc: 0.672639443836 , valid loss: 0.625696944339 , valid acc: 0.673781491414
# 'unwarrentedly'
# epoch: 10 , pass acc: 0.673781491414 , current acc: 0.6885233827
# time taken: 388.26852226257324
# epoch: 11 , training loss: 0.612868307698 , training acc: 0.686262719275 , valid loss: 0.607154706983 , valid acc: 0.6885233827
# 'unwarrentedly'
# epoch: 11 , pass acc: 0.6885233827 , current acc: 0.702472959174
# time taken: 387.9763996601105
# epoch: 12 , training loss: 0.593034886141 , training acc: 0.700707830976 , valid loss: 0.586476610703 , valid acc: 0.702472959174
# 'unwarrentedly'
# epoch: 12 , pass acc: 0.702472959174 , current acc: 0.715714257805
# time taken: 387.7734286785126
# epoch: 13 , training loss: 0.574300099354 , training acc: 0.714652043156 , valid loss: 0.566730175843 , valid acc: 0.715714257805
# 'unwarrentedly'
# epoch: 13 , pass acc: 0.715714257805 , current acc: 0.726134427598
# time taken: 387.5441846847534
# epoch: 14 , training loss: 0.554838651274 , training acc: 0.728542266631 , valid loss: 0.551610186964 , valid acc: 0.726134427598
# 'unwarrentedly'
# epoch: 14 , pass acc: 0.726134427598 , current acc: 0.738115220296
# time taken: 387.3669295310974
# epoch: 15 , training loss: 0.535478397516 , training acc: 0.741883599461 , valid loss: 0.536404311371 , valid acc: 0.738115220296
# 'unwarrentedly'
# epoch: 15 , pass acc: 0.738115220296 , current acc: 0.752605019497
# time taken: 387.3142831325531
# epoch: 16 , training loss: 0.516455953841 , training acc: 0.756094758355 , valid loss: 0.516590906113 , valid acc: 0.752605019497
# 'unwarrentedly'
# epoch: 16 , pass acc: 0.752605019497 , current acc: 0.764573807548
# time taken: 387.1788125038147
# epoch: 17 , training loss: 0.498155501042 , training acc: 0.769520074344 , valid loss: 0.498596039067 , valid acc: 0.764573807548
# 'unwarrentedly'
# epoch: 17 , pass acc: 0.764573807548 , current acc: 0.779603823107
# time taken: 387.2739534378052
# epoch: 18 , training loss: 0.480787412861 , training acc: 0.780287921464 , valid loss: 0.478150906361 , valid acc: 0.779603823107
# 'unwarrentedly'
# epoch: 18 , pass acc: 0.779603823107 , current acc: 0.79099637778
# time taken: 387.3933382034302
# epoch: 19 , training loss: 0.46518139045 , training acc: 0.791433693301 , valid loss: 0.460006147945 , valid acc: 0.79099637778
# 'unwarrentedly'
# epoch: 19 , pass acc: 0.79099637778 , current acc: 0.799843919878
# time taken: 387.584774017334
# epoch: 20 , training loss: 0.450057471288 , training acc: 0.802273525527 , valid loss: 0.448588220405 , valid acc: 0.799843919878
# 'unwarrentedly'
# epoch: 20 , pass acc: 0.799843919878 , current acc: 0.806890739327
# time taken: 387.12575674057007
# epoch: 21 , training loss: 0.436719697968 , training acc: 0.809781025288 , valid loss: 0.435314358139 , valid acc: 0.806890739327
# 'unwarrentedly'
# epoch: 21 , pass acc: 0.806890739327 , current acc: 0.808715467264
# time taken: 387.13577127456665
# epoch: 22 , training loss: 0.425272900649 , training acc: 0.816655651477 , valid loss: 0.429847326098 , valid acc: 0.808715467264
# 'unwarrentedly'
# epoch: 22 , pass acc: 0.808715467264 , current acc: 0.81972387315
# time taken: 387.7452726364136
# epoch: 23 , training loss: 0.414024152331 , training acc: 0.822990386373 , valid loss: 0.414194328015 , valid acc: 0.81972387315
# 'unwarrentedly'
# epoch: 23 , pass acc: 0.81972387315 , current acc: 0.824141641052
# time taken: 387.5673282146454
# epoch: 24 , training loss: 0.403922347087 , training acc: 0.828683249719 , valid loss: 0.408113130179 , valid acc: 0.824141641052
# 'unwarrentedly'
# epoch: 24 , pass acc: 0.824141641052 , current acc: 0.828139241288
# time taken: 387.8240840435028
# epoch: 25 , training loss: 0.39441262334 , training acc: 0.834382110698 , valid loss: 0.401654301714 , valid acc: 0.828139241288
# 'unwarrentedly'
# epoch: 25 , pass acc: 0.828139241288 , current acc: 0.835474176996
# time taken: 387.7122206687927
# epoch: 26 , training loss: 0.385760498891 , training acc: 0.838656257746 , valid loss: 0.387352142192 , valid acc: 0.835474176996
# 'unwarrentedly'
# epoch: 26 , pass acc: 0.835474176996 , current acc: 0.837827122083
# time taken: 387.4422724246979
# epoch: 27 , training loss: 0.377626583043 , training acc: 0.843404309597 , valid loss: 0.382543132872 , valid acc: 0.837827122083
# 'unwarrentedly'
# epoch: 27 , pass acc: 0.837827122083 , current acc: 0.840288102627
# time taken: 387.43717765808105
# epoch: 28 , training loss: 0.369279348142 , training acc: 0.847801431576 , valid loss: 0.375625902794 , valid acc: 0.840288102627
# 'unwarrentedly'
# epoch: 28 , pass acc: 0.840288102627 , current acc: 0.845234087106
# time taken: 387.51235151290894
# epoch: 29 , training loss: 0.361947937437 , training acc: 0.851892615641 , valid loss: 0.367232918704 , valid acc: 0.845234087106
# 'unwarrentedly'
# epoch: 29 , pass acc: 0.845234087106 , current acc: 0.850384148658
# time taken: 387.9372401237488
# epoch: 30 , training loss: 0.354305531233 , training acc: 0.855491897787 , valid loss: 0.358036610044 , valid acc: 0.850384148658
# 'unwarrentedly'
# epoch: 30 , pass acc: 0.850384148658 , current acc: 0.85147658409
# time taken: 388.17532753944397
# epoch: 31 , training loss: 0.347017524977 , training acc: 0.858983200721 , valid loss: 0.355048706891 , valid acc: 0.85147658409
# 'unwarrentedly'
# epoch: 31 , pass acc: 0.85147658409 , current acc: 0.857767106319
# time taken: 387.6140320301056
# epoch: 32 , training loss: 0.340156812169 , training acc: 0.862414516763 , valid loss: 0.3454686226 , valid acc: 0.857767106319
# 'unwarrentedly'
# epoch: 32 , pass acc: 0.857767106319 , current acc: 0.860384152288
# time taken: 387.8507630825043
# epoch: 33 , training loss: 0.334163045371 , training acc: 0.865380925784 , valid loss: 0.339186950445 , valid acc: 0.860384152288
# 'unwarrentedly'
# epoch: 33 , pass acc: 0.860384152288 , current acc: 0.861080431566
# time taken: 387.9463186264038
# epoch: 34 , training loss: 0.328605438426 , training acc: 0.868275347018 , valid loss: 0.335717361622 , valid acc: 0.861080431566
# 'unwarrentedly'
# epoch: 34 , pass acc: 0.861080431566 , current acc: 0.864141655927
# time taken: 388.21125745773315
# epoch: 35 , training loss: 0.321964977143 , training acc: 0.871172769258 , valid loss: 0.328218684209 , valid acc: 0.864141655927
# 'unwarrentedly'
# time taken: 387.6360023021698
# epoch: 36 , training loss: 0.316701433391 , training acc: 0.87255549463 , valid loss: 0.327999472564 , valid acc: 0.863325332751
# 'unwarrentedly'
# time taken: 387.8169741630554
# epoch: 37 , training loss: 0.31144718698 , training acc: 0.874973012147 , valid loss: 0.32726041953 , valid acc: 0.863613443572
# 'unwarrentedly'
# epoch: 37 , pass acc: 0.864141655927 , current acc: 0.867839138763
# time taken: 387.55167531967163
# epoch: 38 , training loss: 0.306871791952 , training acc: 0.877399528034 , valid loss: 0.316149924179 , valid acc: 0.867839138763
# 'unwarrentedly'
# epoch: 38 , pass acc: 0.867839138763 , current acc: 0.871560629319
# time taken: 387.43591356277466
# epoch: 39 , training loss: 0.301748543531 , training acc: 0.87835033861 , valid loss: 0.308907116 , valid acc: 0.871560629319
# 'unwarrentedly'
# epoch: 39 , pass acc: 0.871560629319 , current acc: 0.873289322438
# time taken: 387.1354537010193
# epoch: 40 , training loss: 0.297440080387 , training acc: 0.88095981848 , valid loss: 0.306065901363 , valid acc: 0.873289322438
# 'unwarrentedly'
# time taken: 387.50925517082214
# epoch: 41 , training loss: 0.292363717348 , training acc: 0.882396531859 , valid loss: 0.305312883167 , valid acc: 0.872845144189
# 'unwarrentedly'
# epoch: 41 , pass acc: 0.873289322438 , current acc: 0.875810333088
# time taken: 387.92955255508423
# epoch: 42 , training loss: 0.288300364986 , training acc: 0.88402220748 , valid loss: 0.29933793011 , valid acc: 0.875810333088
# 'unwarrentedly'
# epoch: 42 , pass acc: 0.875810333088 , current acc: 0.876422578189
# time taken: 388.0814006328583
# epoch: 43 , training loss: 0.284168618963 , training acc: 0.884676076798 , valid loss: 0.294235462562 , valid acc: 0.876422578189
# 'unwarrentedly'
# epoch: 43 , pass acc: 0.876422578189 , current acc: 0.877983200736
# time taken: 387.9498145580292
# epoch: 44 , training loss: 0.279747490982 , training acc: 0.886682676479 , valid loss: 0.289908492283 , valid acc: 0.877983200736
# 'unwarrentedly'
# epoch: 44 , pass acc: 0.877983200736 , current acc: 0.879423777739
# time taken: 387.05472779273987
# epoch: 45 , training loss: 0.27586762338 , training acc: 0.888053403905 , valid loss: 0.286239762302 , valid acc: 0.879423777739
# 'unwarrentedly'
# epoch: 45 , pass acc: 0.879423777739 , current acc: 0.879675880343
# time taken: 386.7624583244324
# epoch: 46 , training loss: 0.271792912245 , training acc: 0.888794255064 , valid loss: 0.283171205997 , valid acc: 0.879675880343
# 'unwarrentedly'
# epoch: 46 , pass acc: 0.879675880343 , current acc: 0.881272521196
# time taken: 387.24291014671326
# epoch: 47 , training loss: 0.267692077429 , training acc: 0.890248965309 , valid loss: 0.279679080679 , valid acc: 0.881272521196
# 'unwarrentedly'
# epoch: 47 , pass acc: 0.881272521196 , current acc: 0.882977203876
# time taken: 387.26061391830444
# epoch: 48 , training loss: 0.263716741149 , training acc: 0.890794857845 , valid loss: 0.272470924677 , valid acc: 0.882977203876
# 'unwarrentedly'
# time taken: 387.48317790031433
# epoch: 49 , training loss: 0.260159080659 , training acc: 0.892621492671 , valid loss: 0.271109129344 , valid acc: 0.882052831718
# 'unwarrentedly'
# time taken: 387.880220413208
# epoch: 50 , training loss: 0.256401842843 , training acc: 0.893089399484 , valid loss: 0.27097766198 , valid acc: 0.881800730689
# 'unwarrentedly'
# epoch: 50 , pass acc: 0.882977203876 , current acc: 0.886374562514
# time taken: 388.0613124370575
# epoch: 51 , training loss: 0.252635541876 , training acc: 0.894760065688 , valid loss: 0.261899831737 , valid acc: 0.886374562514
# 'unwarrentedly'
# time taken: 387.4752986431122
# epoch: 52 , training loss: 0.249524080801 , training acc: 0.895371944374 , valid loss: 0.258849081336 , valid acc: 0.885642270653
# 'unwarrentedly'
# time taken: 387.43252325057983
# epoch: 53 , training loss: 0.246023501336 , training acc: 0.896130792095 , valid loss: 0.258339378567 , valid acc: 0.885822340292
# 'unwarrentedly'
# time taken: 387.5087540149689
# epoch: 54 , training loss: 0.242510508998 , training acc: 0.896763666186 , valid loss: 0.255609982011 , valid acc: 0.886182486367
# 'unwarrentedly'
# epoch: 54 , pass acc: 0.886374562514 , current acc: 0.886410579318
# time taken: 387.651202917099
# epoch: 55 , training loss: 0.239846643452 , training acc: 0.897375544925 , valid loss: 0.254699028644 , valid acc: 0.886410579318
# 'unwarrentedly'
# time taken: 387.2391777038574
# epoch: 56 , training loss: 0.236181393601 , training acc: 0.897873445013 , valid loss: 0.252805689553 , valid acc: 0.885930385409
# 'unwarrentedly'
# epoch: 56 , pass acc: 0.886410579318 , current acc: 0.887190889482
# time taken: 387.4705295562744
# epoch: 57 , training loss: 0.23344560979 , training acc: 0.899445132002 , valid loss: 0.250393034262 , valid acc: 0.887190889482
# 'unwarrentedly'
# epoch: 57 , pass acc: 0.887190889482 , current acc: 0.888655475709
# time taken: 386.98757457733154
# epoch: 58 , training loss: 0.230334193366 , training acc: 0.899757069317 , valid loss: 0.244761557836 , valid acc: 0.888655475709
# 'unwarrentedly'
# time taken: 387.01624608039856
# epoch: 59 , training loss: 0.227581413491 , training acc: 0.900518917955 , valid loss: 0.245650857526 , valid acc: 0.888031227892
# 'unwarrentedly'
# time taken: 387.3168156147003
# epoch: 60 , training loss: 0.224996882057 , training acc: 0.901193784001 , valid loss: 0.243568173691 , valid acc: 0.888295332853
# 'unwarrentedly'
# time taken: 387.65186762809753
# epoch: 61 , training loss: 0.221846930971 , training acc: 0.902462529078 , valid loss: 0.249834846334 , valid acc: 0.886902772794
# 'unwarrentedly'
# time taken: 387.43211460113525
# epoch: 62 , training loss: 0.219886988055 , training acc: 0.902138595783 , valid loss: 0.245471675749 , valid acc: 0.886962801111
# 'unwarrentedly'
# epoch: 62 , pass acc: 0.888655475709 , current acc: 0.891404574229
# time taken: 387.1026291847229
# epoch: 63 , training loss: 0.216919349682 , training acc: 0.902990423871 , valid loss: 0.233202621806 , valid acc: 0.891404574229
# 'unwarrentedly'
# epoch: 63 , pass acc: 0.891404574229 , current acc: 0.892040832847
# time taken: 387.5369815826416
# epoch: 64 , training loss: 0.214358164146 , training acc: 0.903992223808 , valid loss: 0.23254014049 , valid acc: 0.892040832847
# 'unwarrentedly'
# time taken: 387.72508811950684
# epoch: 65 , training loss: 0.212082403352 , training acc: 0.904187185541 , valid loss: 0.238222822529 , valid acc: 0.889399772002
# 'unwarrentedly'
