# %%
import re
lines = open('movie_lines.txt', encoding='utf-8', errors='ignore').read().split('\n')
conv_lines = open('movie_conversations.txt', encoding='utf-8', errors='ignore').read().split('\n')

id2line = {}
for line in lines:
    _line = line.split(' +++$+++ ')
    if len(_line) == 5:
        id2line[_line[0]] = _line[4]
        
convs = [ ]
for line in conv_lines[:-1]:
    _line = line.split(' +++$+++ ')[-1][1:-1].replace("'","").replace(" ","")
    convs.append(_line.split(','))
    
questions = []
answers = []

for conv in convs:
    for i in range(len(conv)-1):
        questions.append(id2line[conv[i]])
        answers.append(id2line[conv[i+1]])
        
def clean_text(text):
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"what's", "that is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"how's", "how is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"n't", " not", text)
    text = re.sub(r"n'", "ng", text)
    text = re.sub(r"'bout", "about", text)
    text = re.sub(r"'til", "until", text)
    text = re.sub(r"[-()\"#/@;:<>{}`+=~|.!?,]", "", text)
    return ' '.join([i.strip() for i in filter(None, text.split())])

clean_questions = []
for question in questions:
    clean_questions.append(clean_text(question))
    
clean_answers = []    
for answer in answers:
    clean_answers.append(clean_text(answer))
    
min_line_length = 2
max_line_length = 5
short_questions_temp = []
short_answers_temp = []

i = 0
for question in clean_questions:
    if len(question.split()) >= min_line_length and len(question.split()) <= max_line_length:
        short_questions_temp.append(question)
        short_answers_temp.append(clean_answers[i])
    i += 1

short_questions = []
short_answers = []

i = 0
for answer in short_answers_temp:
    if len(answer.split()) >= min_line_length and len(answer.split()) <= max_line_length:
        short_answers.append(answer)
        short_questions.append(short_questions_temp[i])
    i += 1

question_test = short_questions[500:550]
answer_test = short_answers[500:550]
short_questions = short_questions[:500]
short_answers = short_answers[:500]

# %%
# Out:
# 'what good stuff'

# %%
combined = []
for i in range(len(short_questions)):
    combined.append('%s %s <END>'%(short_questions[i],short_answers[i]))

# %%
from collections import *

def train_chatbot(data, order=4):
    lm = defaultdict(Counter)
    for i in range(len(data)-order):
        history, char = data[i:i+order], data[i+order]
        lm[' '.join(history)][char]+=1
    def normalize(counter):
        s = float(sum(counter.values()))
        return [(c,cnt/s) for c,cnt in counter.items()]
    outlm = {hist:normalize(chars) for hist, chars in lm.items()}
    return outlm

# %%
# %%time
lm = train_chatbot((' '.join(combined)).split(), order=1)
# Out:
# CPU times: user 20.3 ms, sys: 5 µs, total: 20.3 ms
# Wall time: 19.6 ms

# %%
lm[short_questions[1]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-5d5a697e0ebf> in <module>()
# ----> 1 lm[short_questions[1]]
#
# KeyError: 'she okay'

# %%
lm
# Out:
# {'britain<END> this way sungs': [('gettin', 1.0)],
#  'it already<END> they think': [('i', 1.0)],
#  'sec<END> that seems very': [('unlikely', 1.0)],
#  'so that is unique': [('not', 1.0)],
#  'i have seen the': [('manuscript<END>', 1.0)],
#  'can uramu him<END> he': [('did', 1.0)],
#  'guess so<END> specialty product': [('you', 1.0)],
#  'or he dies please': [('come', 1.0)],
#  'czech how you erase': [('this<END>', 1.0)],
#  'know what you did': [('who', 1.0)],
#  'the money is good': [('as', 1.0)],
#  'daddy no just for': [('a', 1.0)],
#  'drive awhile i ai': [('not', 1.0)],
#  'looking for a timer<END>': [('where', 1.0)],
#  'when did she die': [('is', 1.0)],
#  'a lunatic i beg': [('your', 1.0)],
#  'would you lie<END> i': [('should', 1.0)],
#  'be i will be': [('another<END>', 1.0)],
#  'yeah lots see get': [('your', 1.0)],
#  'get the girl<END> hey': [('do', 1.0)],
#  'famous then do it': [('asshole<END>', 1.0)],
#  'is inside the complex': [('you', 1.0)],
#  'she die<END> when did': [('she', 1.0)],
#  'origin who do you': [('think', 1.0)],
#  'but i<END> but i': [('i', 1.0)],
#  'alice<END> i do not': [('get', 1.0)],
#  'then how could i': [('not<END>', 1.0)],
#  "things lit<END> let's go": [("let's", 1.0)],
#  'i did felt like': [('a', 1.0)],
#  'better<END> why not it': [('is', 1.0)],
#  'cool pictures you a': [('fan', 1.0)],
#  'am sorry<END> you do': [('not', 1.0)],
#  'it forget her sister': [('then<END>', 1.0)],
#  'what then<END> what then': [('it', 1.0)],
#  'right at our oneeyed': [('friend<END>', 1.0)],
#  'monster zorg i know<END>': [('who', 1.0)],
#  'priest vito cornelius<END> have': [('you', 1.0)],
#  'i will handle it<END>': [('who', 1.0)],
#  'the colony dead on': [('all', 1.0)],
#  'not bad not bad<END>': [('you', 1.0)],
#  'new britain<END> this way': [('sungs', 1.0)],
#  'it<END> what are you': [('laughing', 1.0)],
#  'it was freddy enough': [('of', 1.0)],
#  'am coming with you<END>': [('i', 1.0)],
#  'is not it incredibly': [('obvious', 1.0)],
#  'love you<END> there you': [('go', 1.0)],
#  'of it which parts<END>': [('cool', 1.0)],
#  'great tits<END> you are': [('sure', 1.0)],
#  'don alonso de bobadilla': [('yes', 1.0)],
#  'year who was your': [('teacher<END>', 1.0)],
#  'to drive awhile i': [('ai', 1.0)],
#  'language<END> learning language which': [('one<END>', 1.0)],
#  "harder there's nothing harder<END>": [('what', 1.0)],
#  'who are you calling': [('mrs', 1.0)],
#  'is the worst you': [('get', 1.0)],
#  'i know what you': [('did<END>', 0.5), ('did', 0.5)],
#  'was a wolf<END> aw': [('come', 1.0)],
#  'is my collar well': [('he', 1.0)],
#  'do not know<END> we': [('are', 1.0)],
#  'up<END> you set me': [('up', 1.0)],
#  'promise cross my heart<END>': [('cross', 1.0)],
#  'have seen the manuscript<END>': [('what', 1.0)],
#  'been here long<END> this': [('is', 1.0)],
#  'no shit<END> it is': [('okay', 1.0)],
#  'i am nuts that': [('is', 1.0)],
#  'this do what<END> put': [('your', 1.0)],
#  'in vienna then you': [('must', 1.0)],
#  'job yes the money': [('is', 1.0)],
#  'me skipper yes griff<END>': [('now', 1.0)],
#  'are you laughing about': [('napoleon', 1.0)],
#  'he look like you': [('might', 1.0)],
#  'sir well there it': [('is<END>', 1.0)],
#  'were divorced<END> valo massa': [('chacha', 1.0)],
#  'like shit<END> akina delutan': [('noushan', 1.0)],
#  'duties yes doctor<END> oh': [('miss', 1.0)],
#  'oh yes when may': [('i', 1.0)],
#  'dies please come on': [('alice<END>', 1.0)],
#  'a she you noticed<END>': [('good', 1.0)],
#  'okay fine<END> that obvious': [('huh', 1.0)],
#  "'bye now sweetheart goodbye": [('daddy<END>', 1.0)],
#  'was reading i was': [('reading', 1.0)],
#  'put your pilot on': [('he', 1.0)],
#  'yes<END> yes indeed and': [('german<END>', 1.0)],
#  'killing me do not<END>': [('who', 1.0)],
#  'there is only one': [('bed<END>', 1.0)],
#  'you heard wrong does': [('not', 1.0)],
#  'musta missed it<END> you': [('are', 1.0)],
#  'to me hudson<END> how': [('much', 1.0)],
#  'go home you cannot<END>': [('that', 1.0)],
#  'i think so sing': [('it', 1.0)],
#  'another two hours<END> what': [('did', 1.0)],
#  'you might not kill': [('it', 1.0)],
#  'proceed inside<END> yes hicks': [('hudson', 1.0)],
#  'not sure<END> you making': [('any', 1.0)],
#  'something not at all<END>': [('not', 1.0)],
#  'you brought the money': [('right', 1.0)],
#  'the kitchen very nice<END>': [('the', 1.0)],
#  'call me tom alright': [('tom<END>', 1.0)],
#  'go you set me': [('up<END>', 1.0)],
#  'read twenty eight<END> six': [('days', 1.0)],
#  'george to the to': [('the', 1.0)],
#  'i mean whereabouts<END> what': [('blood', 1.0)],
#  'it why would i': [('do', 1.0)],
#  'how you doing man': [('not', 1.0)],
#  'heart and hope to': [('die<END>', 1.0)],
#  'copy stand by tower': [('tower', 1.0)],
#  'may i ask<END> when': [('may', 1.0)],
#  'like that then you': [('screwed', 1.0)],
#  'did my work please': [('you', 0.5), ('you<END>', 0.5)],
#  'okay<END> are you hit': [('no', 1.0)],
#  'after torpedo room report<END>': [('that', 1.0)],
#  'oh yes please<END> i': [('am', 1.0)],
#  'george<END> back off george': [('but', 1.0)],
#  "noushan 'scuse me<END> vito": [('cor', 1.0)],
#  'promised him to machine<END>': [('that', 1.0)],
#  'cornelius<END> have you pulled': [('yourself', 1.0)],
#  'i hope so<END> they': [('do', 1.0)],
#  'jack shot him well': [('it', 1.0)],
#  'sir he is not<END>': [('no', 1.0)],
#  'let go you set': [('me', 1.0)],
#  'do that<END> we copy': [('stand', 1.0)],
#  'ambitious<END> you defend yourself': [('admirably', 1.0)],
#  'on one hearing only': [('i', 1.0)],
#  'picture and that fits<END>': [('why', 1.0)],
#  'me up i just': [('wanted<END>', 1.0)],
#  'was that evidence of': [('a', 1.0)],
#  'you been nowhere hi': [('daddy<END>', 1.0)],
#  'back try and take': [('it<END>', 1.0)],
#  'honey where is czech': [('girl<END>', 1.0)],
#  'the money right here<END>': [('what', 1.0)],
#  'it true do you': [('believe', 1.0)],
#  'was freddy enough of': [('that', 1.0)],
#  'course not do you': [('have', 1.0)],
#  'private investigator that is': [('right<END>', 1.0)],
#  'it is stupid<END> it': [('is', 1.0)],
#  'where is czech girl<END>': [('speak', 1.0)],
#  'darling<END> oh i cannot': [('stand', 1.0)],
#  'come with me<END> you': [('bring', 1.0)],
#  'disappointed<END> do not bother': [('i', 1.0)],
#  'what shall we do': [('tea', 1.0)],
#  'seems very unlikely yes': [('i', 1.0)],
#  'the cash man been': [('here', 1.0)],
#  'not therefore<END> well i': [('will', 1.0)],
#  'uh matthew back off': [('george<END>', 1.0)],
#  'cigarettes oh sure<END> delusions': [('and', 1.0)],
#  'welcome<END> finished what learning': [('language<END>', 1.0)],
#  'name<END> stop talking you': [('got', 1.0)],
#  'for a timer<END> where': [('is', 1.0)],
#  'it is stupid it': [('is', 1.0)],
#  'taking a bath<END> taking': [('a', 1.0)],
#  'no one i heard': [('voices<END>', 1.0)],
#  'great time honey but': [('who', 1.0)],
#  'would you know<END> keep': [('stalling', 1.0)],
#  'doctor<END> oh miss price': [('yes', 1.0)],
#  'what do you mean': [('now<END>', 0.5), ('is', 0.5)],
#  'no she is fine': [('i', 1.0)],
#  'do not understand<END> for': [('a', 1.0)],
#  'next time phone ahead': [('how', 1.0)],
#  'it funny to us': [('it', 1.0)],
#  'where is she taking': [('a', 1.0)],
#  'then you screwed up<END>': [('tell', 1.0)],
#  'you very much hal<END>': [('i', 1.0)],
#  'this<END> shut up does': [('it', 1.0)],
#  'one cell survived have': [('you', 1.0)],
#  'that is this an': [('attempted', 1.0)],
#  'he say who cares<END>': [('pick', 1.0)],
#  'i beg your pardon': [('it', 1.0)],
#  'then<END> it is about': [('time', 1.0)],
#  'this<END> ah you have': [('heard', 1.0)],
#  'brought the girl remember': [('the', 1.0)],
#  'are<END> mommyi mean ripleyi': [('am', 1.0)],
#  'colonists sixty maybe seventy': [('families<END>', 1.0)],
#  'are just reading me<END>': [('range', 1.0)],
#  'will get us maybe': [('maybe', 1.0)],
#  'feel that yes i': [('did<END>', 1.0)],
#  'i guess they are': [('stupid<END>', 1.0)],
#  "must be billy's girl": [('come', 1.0)],
#  'wah where are<END> mommyi': [('mean', 1.0)],
#  'going<END> where are we': [('going', 1.0)],
#  'did you manage it<END>': [('esdras', 1.0)],
#  "'flying saucer'<END> but if": [('they', 1.0)],
#  'then<END> did you like': [('it', 1.0)],
#  'understand<END> you are killing': [('me', 1.0)],
#  'lay down stay down': [('bobby<END>', 1.0)],
#  'outta here what the': [('hell', 1.0)],
#  'she<END> newt newt wake': [('up', 1.0)],
#  'with the tenors also': [('identical<END>', 1.0)],
#  'we are under attack': [('where', 1.0)],
#  'on<END> put your pilot': [('on', 1.0)],
#  "bianca's sister the mewling": [('rampalian', 1.0)],
#  'a secret<END> yes thank': [('you', 1.0)],
#  'too that is the': [('story<END>', 1.0)],
#  'already<END> they think i': [('am', 1.0)],
#  'it down what is': [('this<END>', 1.0)],
#  'alice so did dan<END>': [('mark', 1.0)],
#  'not excellency<END> what work': [('a', 1.0)],
#  'cause and origin who': [('do', 1.0)],
#  'it is it true<END>': [('is', 1.0)],
#  'herr mozart that is': [('right<END>', 1.0)],
#  'is he todd watson': [('the', 1.0)],
#  'i did no you': [('did', 1.0)],
#  'i presume<END> cannot you': [('take', 1.0)],
#  'wrong does not look': [('like', 1.0)],
#  'also to bring medicine': [('chief', 1.0)],
#  'pretty good thank you<END>': [('thank', 1.0)],
#  'in the kitchen<END> what': [('are', 1.0)],
#  'you calling mrs christian<END>': [('anything', 1.0)],
#  'the microwave make anyone': [('cry', 1.0)],
#  'a commoner<END> what do': [('you', 1.0)],
#  'are you okay yeah': [('i', 1.0)],
#  'no go ahead thanks': [('appreciate', 1.0)],
#  'what for<END> what is': [('this', 1.0)],
#  'oveur mr kurtz i': [('presume<END>', 1.0)],
#  "'c' why he is": [('carrying', 1.0)],
#  'the west indies<END> how': [('are', 1.0)],
#  'you must be mad<END>': [('do', 1.0)],
#  'so which dakota you': [('from', 1.0)],
#  'is a jew so': [('was', 1.0)],
#  'okay yeah i am': [('just', 1.0)],
#  'divorced<END> your health ta': [("ss'trakyona'<END>", 1.0)],
#  'absolutely sure i have': [('seen', 1.0)],
#  'life<END> i poisoned his': [('life', 1.0)],
#  'what the fuck i': [('promised', 1.0)],
#  'not know well ask': [('her<END>', 1.0)],
#  'yes i remember<END> my': [('letters', 1.0)],
#  'think this will work': [('no', 1.0)],
#  'thank you<END> grazie mio': [('caro', 1.0)],
#  'so<END> they do to': [('they', 1.0)],
#  'got shot<END> you cannot': [('buy', 1.0)],
#  'how do i look': [('like', 0.5), ('you', 0.5)],
#  'me hudson<END> how much': [('time', 1.0)],
#  'you know<END> keep stalling': [('alright', 1.0)],
#  'you feeling fernando not': [('bad<END>', 1.0)],
#  'not say anything where': [('are', 1.0)],
#  'that korfin<END> tomorrow at': [('lunch', 1.0)],
#  'did i am afraid': [('not', 1.0)],
#  'ago yes you must': [('be', 1.0)],
#  'bill goodbye darling<END> oh': [('i', 1.0)],
#  'pay money yeah dummy': [('money<END>', 1.0)],
#  'spires<END> and also to': [('bring', 1.0)],
#  'gordon<END> mel gordon i': [('still', 1.0)],
#  'perfect mr president<END> smoking': [('i', 1.0)],
#  'get your boots<END> see': [('get', 1.0)],
#  "well let's roll george": [('to', 1.0)],
#  'think oh yeah<END> you': [('are', 1.0)],
#  'minutes<END> plenty twentysix minutes': [('we', 1.0)],
#  'poisoned his life<END> i': [('poisoned', 1.0)],
#  'was dreaming again i': [('would', 1.0)],
#  'that and do they': [('believe', 1.0)],
#  'machine<END> that is five': [('thousand', 1.0)],
#  'was at hand<END> he': [('asked', 1.0)],
#  'is easy to learn<END>': [('what', 1.0)],
#  'may i ask by': [('whom', 1.0)],
#  'a bath<END> taking a': [('bath', 1.0)],
#  'his name<END> stop talking': [('you', 1.0)],
#  'ha ha srai amsick': [('srai', 1.0)],
#  'i musta missed it<END>': [('you', 1.0)],
#  'think so<END> i think': [('so', 1.0)],
#  'it cannot<END> what are': [('you', 1.0)],
#  'why not<END> why not': [('it', 1.0)],
#  'i am cominghold on<END>': [('how', 1.0)],
#  'a b<END> captain oveur': [('mr', 1.0)],
#  'how is she doing': [('okay', 1.0)],
#  'you here am i': [('not', 1.0)],
#  'the man he is': [('here', 1.0)],
#  'what does she want': [('i', 1.0)],
#  'and origin who do': [('you', 1.0)],
#  'way he is mine<END>': [('he', 1.0)],
#  'you can turn around<END>': [('tell', 1.0)],
#  'give me absolution<END> i': [('have', 1.0)],
#  'him alone<END> leave him': [('alone', 1.0)],
#  'fast do you have': [('it<END>', 1.0)],
#  'hundred bucks a date': [('forget', 1.0)],
#  'seal the door<END> you': [('promise', 1.0)],
#  'keep stalling alright i': [('am', 1.0)],
#  'get out how many': [('people', 1.0)],
#  'you pulled yourself together': [('not', 1.0)],
#  'is here<END> why are': [('you', 1.0)],
#  'belongings her belongings<END> none': [('too', 1.0)],
#  "is her bianca's sister": [('the', 1.0)],
#  'luck of course<END> it': [('is', 1.0)],
#  'do they believe it<END>': [('and', 1.0)],
#  'giacomo colon<END> don alonso': [('de', 1.0)],
#  'am fine fine<END> you': [('and', 1.0)],
#  "let's go let's go": [('fucking', 1.0)],
#  'you up friday then': [('oh', 1.0)],
#  'write it why not<END>': [('why', 1.0)],
#  'but not his body<END>': [('but', 1.0)],
#  'you thirsty i am': [('on', 1.0)],
#  'confutatis maledictis we ended': [('in', 1.0)],
#  'below radiation levelconstantly rising<END>': [('who', 1.0)],
#  'yeah it is stupid<END>': [('yeah', 1.0)],
#  'sox<END> you played for': [('the', 1.0)],
#  'acting strangely<END> is david': [('acting', 1.0)],
#  'it is stupid i': [('guess', 1.0)],
#  'fart backwards<END> oh ha': [('ha', 1.0)],
#  "these things lit<END> let's": [('go', 1.0)],
#  'are we going to': [('take', 1.0)],
#  'who are you i': [('brought', 1.0)],
#  'herr mozart yes what': [('about', 1.0)],
#  'hi honey<END> did you': [('get', 1.0)],
#  'not be late<END> so': [('that', 1.0)],
#  'in the chest<END> in': [('the', 1.0)],
#  'how is your financial': [('situation', 1.0)],
#  'her<END> yes my love': [('these', 1.0)],
#  'to try it again<END>': [('last', 1.0)],
#  'that<END> great place for': [('lunch', 1.0)],
#  'again<END> seems to be': [('all', 1.0)],
#  'is it<END> that is': [('the', 1.0)],
#  'seems to be all': [('around', 1.0)],
#  'well there it is<END>': [('your', 1.0)],
#  'they are stupid<END> was': [('it', 1.0)],
#  'later good luck thank': [('you<END>', 1.0)],
#  'the routine you are': [('married<END>', 1.0)],
#  'indies<END> how are you': [('feeling', 1.0)],
#  'hear me out<END> still': [('nothing', 1.0)],
#  'accomplishment i kill someone': [('famous<END>', 1.0)],
#  'yeah i am just': [('aces<END>', 1.0)],
#  'timer<END> where is she': [('taking', 1.0)],
#  'that survived actually only': [('one', 1.0)],
#  'here so am i<END>': [("sowho's", 1.0)],
#  'talk to you<END> that': [('is', 1.0)],
#  'what learning language<END> learning': [('language', 1.0)],
#  "time a deal's a": [('deal<END>', 1.0)],
#  'do you have a': [('daughter<END>', 0.5), ('daughter', 0.5)],
#  'there forget it i': [('am', 1.0)],
#  'she want i do': [('not', 1.0)],
#  'why i am asking<END>': [('is', 1.0)],
#  'here<END> that is her': [("bianca's", 1.0)],
#  'what i said<END> that': [('is', 1.0)],
#  'do not know<END> i': [('do', 1.0)],
#  'am not leaving you': [('i', 1.0)],
#  'serious shut up look<END>': [('we', 1.0)],
#  'over<END> which passenger is': [('joe', 1.0)],
#  'damage immediately after torpedo': [('room', 1.0)],
#  'harcourt harcourt is dead<END>': [('how', 1.0)],
#  'the news nah i': [('musta', 1.0)],
#  'the news i hear': [('twombley', 1.0)],
#  'something back home<END> my': [('point', 1.0)],
#  'sir<END> are you herr': [('mozart', 1.0)],
#  'yeah i guess<END> you': [('think', 1.0)],
#  'minute<END> you the new': [('guy', 1.0)],
#  'you were not then': [('why', 1.0)],
#  'i told you<END> no': [('you', 1.0)],
#  'go about your duties': [('yes', 1.0)],
#  'your distraught it will': [('help<END>', 1.0)],
#  'what<END> appointment to what': [('viceroy', 1.0)],
#  'the door<END> you promise': [('cross', 1.0)],
#  'cannot lock up talk': [('to', 1.0)],
#  'shit<END> it is okay': [('stick', 1.0)],
#  'did he look<END> dr': [('hirsch', 1.0)],
#  'you from north actually': [('how', 1.0)],
#  'married no are you': [('proposing<END>', 1.0)],
#  'my favorites<END> yeah one': [('of', 1.0)],
#  'stolen<END> we are saved': [('i', 1.0)],
#  'work please you how': [('could', 1.0)],
#  "do what<END> who's that": [('patrick', 1.0)],
#  'room<END> that is going': [('on', 1.0)],
#  'you<END> get out how': [('many', 1.0)],
#  'ahead thanks appreciate it<END>': [('what', 1.0)],
#  'leaving you i am': [('so', 1.0)],
#  'would new worlds create': [('new', 1.0)],
#  'ai not tired yet<END>': [('pay', 1.0)],
#  "aces<END> who's jacob my": [('baby<END>', 1.0)],
#  'you are just reading': [('me<END>', 1.0)],
#  'sixty maybe seventy families<END>': [('sixty', 1.0)],
#  'we go now<END> let': [('go', 1.0)],
#  'i look you look': [('very', 1.0)],
#  'you elaine i love': [('you<END>', 1.0)],
#  'stupid<END> was it funny': [('to', 1.0)],
#  'no one<END> no one': [('i', 1.0)],
#  'there you go love': [('you', 0.5), ('you<END>', 0.5)],
#  'telling you why not<END>': [('i', 1.0)],
#  'product you are learning<END>': [('you', 1.0)],
#  'you made the front': [('page<END>', 1.0)],
#  'is right<END> in there': [('show', 1.0)],
#  'you read my mind': [('put', 1.0)],
#  'be late<END> so that': [('is', 1.0)],
#  'mozart thank you oh': [('thank', 1.0)],
#  'nicky what do you': [('want<END>', 1.0)],
#  'high deers have ears': [('too<END>', 1.0)],
#  'they will get us': [('maybe', 1.0)],
#  'i was not sure<END>': [('you', 1.0)],
#  'a prostitute yes i': [('considered', 1.0)],
#  'excuse acting the way': [('we', 1.0)],
#  'collar well he killed': [('my', 1.0)],
#  'not mean that yeah': [('i', 1.0)],
#  'complex you are just': [('reading', 1.0)],
#  'you manage it<END> esdras': [('is', 1.0)],
#  'and german oh yes': [('absolutely', 1.0)],
#  'from north actually how': [('would', 1.0)],
#  'that is my girl<END>': [('go', 1.0)],
#  'am so relieved<END> what': [('is', 1.0)],
#  'he is busy being': [('dead<END>', 1.0)],
#  'give me ulcers that': [('is', 1.0)],
#  'with you yes yes': [('come', 1.0)],
#  'share information we do<END>': [('yeah', 1.0)],
#  'at lunch you ready<END>': [('that', 1.0)],
#  'those are her belongings<END>': [('those', 1.0)],
#  'then it is stupid<END>': [('it', 1.0)],
#  'problem i am camera': [('shy<END>', 1.0)],
#  'before the shooting how': [('was', 1.0)],
#  'think jack shot him<END>': [('you', 1.0)],
#  'to go outside naw': [('right', 1.0)],
#  'here<END> i am serious': [('here', 1.0)],
#  'do it asshole<END> you': [('promise', 1.0)],
#  'i kill someone famous': [('then', 1.0)],
#  'it is<END> get outta': [('there', 1.0)],
#  'speak english you said': [('speak', 1.0)],
#  'baby<END> my baby what': [('you', 1.0)],
#  'sick<END> what does she': [('want', 1.0)],
#  'commissioner aquarius<END> did you': [('feel', 1.0)],
#  'you proposing<END> hi i': [('am', 1.0)],
#  'you believe it should': [('i<END>', 1.0)],
#  'i know the routine': [('you', 1.0)],
#  'let me talk to': [('you<END>', 1.0)],
#  "coffee's perked when did": [('she', 1.0)],
#  'good<END> yes the money': [('is', 1.0)],
#  'have he had fish<END>': [('i', 1.0)],
#  'plenty twentysix minutes we': [('are', 1.0)],
#  'fortyone<END> he is pretty': [('okay', 1.0)],
#  'with you<END> i am': [('coming', 1.0)],
#  "meters let's get these": [('things', 1.0)],
#  'your clothing reeks of': [('it<END>', 1.0)],
#  'of them just lies': [('colon', 1.0)],
#  'is mrs brown she': [('is', 1.0)],
#  'wet sponge<END> you promise': [('you', 1.0)],
#  'only i think so': [('sire', 1.0)],
#  'yeah yeah jesus<END> are': [('you', 1.0)],
#  'what dead who is': [('dead<END>', 1.0)],
#  'nah i musta missed': [('it<END>', 1.0)],
#  'carrying a bomb a': [('b<END>', 1.0)],
#  'me<END> so which dakota': [('you', 1.0)],
#  'dan<END> mark are you': [('okay', 1.0)],
#  'save it sure hicks<END>': [('the', 1.0)],
#  'red sox you played': [('for', 1.0)],
#  'is machine<END> who is': [('machine', 1.0)],
#  'way hear me out<END>': [('still', 1.0)],
#  'anything where are we': [('going<END>', 1.0)],
#  'ashamed<END> i am so': [('ashamed', 1.0)],
#  'cell survived have you': [('identified', 1.0)],
#  'serious here<END> i am': [('serious', 1.0)],
#  'are right you are': [('hopeless<END>', 1.0)],
#  'come on<END> how much': [('half', 1.0)],
#  'at all<END> a hundred': [('bucks', 1.0)],
#  'identified it<END> is that': [('better', 1.0)],
#  'was all of these<END>': [('no', 1.0)],
#  'you may not okay': [('fine<END>', 1.0)],
#  'is stupid<END> yeah it': [('is', 1.0)],
#  'talk to me hudson<END>': [('how', 1.0)],
#  'gordon could be<END> yeah': [('lots', 1.0)],
#  'date tonight yeah guess': [('so<END>', 1.0)],
#  'god he killed them<END>': [('excuse', 1.0)],
#  'it i do not': [('know<END>', 1.0)],
#  'one<END> you thirsty i': [('am', 1.0)],
#  'a minute<END> you the': [('new', 1.0)],
#  'no way hear me': [('out<END>', 1.0)],
#  'money<END> how you doing': [('man', 1.0)],
#  'be all around what': [('about', 1.0)],
#  'so<END> specialty product you': [('are', 1.0)],
#  'to what<END> appointment to': [('what', 1.0)],
#  'you said speak czech': [('how', 1.0)],
#  'i look like shit<END>': [('akina', 1.0)],
#  'do what you know<END>': [('you', 1.0)],
#  'learning language<END> learning language': [('which', 1.0)],
#  'why would you ask': [('why', 1.0)],
#  'the shooting how was': [('she<END>', 1.0)],
#  "'scuse me<END> vito cor": [('nilious', 1.0)],
#  'do that sorry babe<END>': [('you', 1.0)],
#  'where are you going<END>': [('daddy', 1.0)],
#  'all like that are': [('you', 1.0)],
#  'herself<END> her favorite uncle': [('dead', 1.0)],
#  'she said yes thank': [('god<END>', 1.0)],
#  'he no sir he': [('is', 1.0)],
#  'i promised him to': [('machine<END>', 1.0)],
#  'i will be another<END>': [('tell', 1.0)],
#  'by the red sox': [('you', 1.0)],
#  'to live with how': [('would', 1.0)],
#  'hamas uhyou are welcome<END>': [('finished', 1.0)],
#  'smoking your clothing reeks': [('of', 1.0)],
#  'i poisoned his life': [('but', 1.0)],
#  'i am honey where': [('is', 1.0)],
#  "here's okay<END> five bills": [('five', 1.0)],
#  'heart mozart thank you': [('oh', 1.0)],
#  'true thank you very': [('much', 1.0)],
#  'financial situation it could': [('not', 1.0)],
#  'you ready<END> that is': [('he', 1.0)],
#  'well thanks i<END> no': [("there's", 1.0)],
#  'i will be right': [('back<END>', 1.0)],
#  'will help<END> what is': [('it', 1.0)],
#  'him alone fuck off<END>': [('call', 1.0)],
#  'man to live with': [('how', 1.0)],
#  'going to take a': [('picture<END>', 1.0)],
#  'camera down oleg<END> i': [('am', 1.0)],
#  'under attack<END> we are': [('under', 1.0)],
#  'sungs gettin high<END> sungs': [('gettin', 1.0)],
#  'whitehouse next time phone': [('ahead', 1.0)],
#  'down oleg<END> i am': [('serious', 1.0)],
#  'you see roofs towers': [('palaces', 1.0)],
#  'hope so<END> they do': [('to', 1.0)],
#  'a job yes the': [('money', 1.0)],
#  'that is right<END> put': [('it', 1.0)],
#  'attack where is my': [('family<END>', 1.0)],
#  'hours<END> what did he': [('have', 1.0)],
#  'was she running from': [('i', 1.0)],
#  'do not<END> hey sweet': [('cheeks', 1.0)],
#  'take a guess wellnot': [('for', 1.0)],
#  'what who<END> okay you': [('ready', 1.0)],
#  'not bargaining then you': [('are', 1.0)],
#  'what are you laughing': [('about', 1.0)],
#  'shot in the chest<END>': [('in', 1.0)],
#  'it is harcourt harcourt': [('is', 1.0)],
#  'like it<END> hey you': [('are', 1.0)],
#  'that is the running': [('time', 1.0)],
#  'yet<END> pay money yeah': [('dummy', 1.0)],
#  'bring the cigarettes oh': [('sure<END>', 1.0)],
#  'out<END> still nothing from': [('the', 1.0)],
#  'ahead how is that<END>': [('where', 1.0)],
#  'cannot<END> what are you': [('doing', 1.0)],
#  'yeah i know the': [('routine', 1.0)],
#  'a private investigator<END> you': [('are', 1.0)],
#  'house situation room<END> that': [('is', 1.0)],
#  'my family<END> where is': [('my', 1.0)],
#  'what was that korfin<END>': [('tomorrow', 1.0)],
#  'specialty product you are': [('learning<END>', 1.0)],
#  'shut up does it': [('hurt<END>', 1.0)],
#  'you stay with me': [('no', 1.0)],
#  'want to try it': [('again<END>', 1.0)],
#  'are you calling mrs': [('christian<END>', 1.0)],
#  'not something back home<END>': [('my', 1.0)],
#  'the bathroom<END> yes daddy': [("'bye", 1.0)],
#  'pretty okay i was': [('not', 1.0)],
#  'ask by whom bartolome': [('and', 1.0)],
#  'would you ask why': [('would', 1.0)],
#  'all channels<END> what is': [('it', 1.0)],
#  'see roofs towers palaces': [('spires<END>', 1.0)],
#  'beautiful jesus do not': [('do', 1.0)],
#  'in the chest no': [('i', 1.0)],
#  'to the to the': [('beach<END>', 1.0)],
#  'yes indeed and german<END>': [('and', 1.0)],
#  "there's nothing to see<END>": [('dear', 1.0)],
#  'do not do that<END>': [('jesus', 1.0)],
#  'duty<END> why not something': [('back', 1.0)],
#  'you next week<END> in': [('the', 1.0)],
#  'yeah it is stupid': [('i', 1.0)],
#  'hell happened<END> hi frank': [('coming', 1.0)],
#  'good work alice so': [('did', 1.0)],
#  'duck how did he': [('look<END>', 1.0)],
#  'am not smoking your': [('clothing', 1.0)],
#  'my love these gentlemen': [('are', 1.0)],
#  'girl<END> he is a': [('she', 1.0)],
#  'the new guy so': [('they', 1.0)],
#  'considered becoming a prostitute': [('yes', 1.0)],
#  'handling it sir<END> this': [('is', 1.0)],
#  'fuck off<END> call me': [('tom', 1.0)],
#  'is this those are': [('her', 1.0)],
#  'guess wellnot for another': [('two', 1.0)],
#  'is fine i am': [('so', 1.0)],
#  'you believe it<END> do': [('you', 1.0)],
#  'his body what difference': [('does', 1.0)],
#  'page<END> hi it is': [('me', 1.0)],
#  'hudson<END> how much time': [('plenty', 1.0)],
#  'it is easy to': [('learn<END>', 1.0)],
#  'are you herr mozart': [('that', 1.0)],
#  'on miss price call': [('me', 1.0)],
#  'you<END> that is wrong': [('with', 1.0)],
#  'is going on we': [('are', 1.0)],
#  'do that do what<END>': [('do', 1.0)],
#  'oveur over poached not': [('over', 1.0)],
#  'oleg<END> i am serious': [('shut', 1.0)],
#  'not bad<END> you want': [('to', 1.0)],
#  'it<END> and do they': [('believe', 1.0)],
#  'i ask<END> when may': [('i', 1.0)],
#  'he is hicks<END> hudson': [('sir', 1.0)],
#  'just one year who': [('was', 1.0)],
#  'okay<END> five bills five': [('on', 1.0)],
#  'it<END> esdras is a': [('jew', 1.0)],
#  'doing here you have': [('got', 1.0)],
#  'voices<END> i am not': [('telling', 1.0)],
#  'todd watson the assistant': [('manager<END>', 1.0)],
#  'front page<END> hi it': [('is', 1.0)],
#  'here am i not': [('welcome<END>', 1.0)],
#  'cannot wait well promise': [('then<END>', 1.0)],
#  'for the dead what': [('dead', 1.0)],
#  'a timer<END> where is': [('she', 1.0)],
#  'this it is harcourt<END>': [('it', 1.0)],
#  "why not because there's": [('nothing', 1.0)],
#  'do good work alice': [('so', 1.0)],
#  'sister then<END> it is': [('about', 1.0)],
#  'kill someone famous<END> i': [('kill', 1.0)],
#  'you oh thank you<END>': [('grazie', 1.0)],
#  "what<END> who's that patrick": [('verona', 1.0)],
#  'price yes doctor<END> did': [('he', 1.0)],
#  'parts<END> cool pictures you': [('a', 1.0)],
#  'of that crap<END> ttthanks': [('alice', 1.0)],
#  'i love you<END> you': [('could', 1.0)],
#  'scared i know honey': [('me', 1.0)],
#  'did she die<END> when': [('did', 1.0)],
#  'bullshit you heard wrong': [('does', 1.0)],
#  'down what is this<END>': [('why', 1.0)],
#  'antonio<END> how could i': [('not', 1.0)],
#  'you why not<END> i': [('cannot', 1.0)],
#  'one all 900<END> you': [('noticed', 1.0)],
#  'back already<END> how you': [('doing', 1.0)],
#  'on all channels<END> what': [('is', 1.0)],
#  'whereabouts<END> what blood on': [('your', 1.0)],
#  'right there you go': [('love', 1.0)],
#  'is your excuse acting': [('the', 1.0)],
#  'thank you<END> that is': [('right', 1.0)],
#  'i figured you share': [('information', 1.0)],
#  'that is what i': [('said', 0.5), ('said<END>', 0.5)],
#  'station is empty yeah': [('this', 1.0)],
#  'do you see roofs': [('towers', 1.0)],
#  'a wet sponge<END> you': [('promise', 1.0)],
#  'but who what<END> he': [('is', 1.0)],
#  'right<END> put it down': [('what', 1.0)],
#  'you think oh yeah<END>': [('you', 1.0)],
#  'is our friend<END> oh': [('yes', 1.0)],
#  'congratulations did you like': [('it', 1.0)],
#  'guess get some sleep<END>': [('what', 1.0)],
#  'days ago yes you': [('must', 1.0)],
#  'pilot on he is': [('busy', 1.0)],
#  'is this it is': [('harcourt<END>', 1.0)],
#  'how is that<END> where': [('is', 1.0)],
#  'pretty old it belongs': [('to', 1.0)],
#  'her go first the': [('money<END>', 1.0)],
#  'appointment to what viceroy': [('of', 1.0)],
#  'hi joey<END> where have': [('you', 1.0)],
#  'that is your accomplishment': [('i', 1.0)],
#  "ss'trakyona'<END> well let's roll": [('george', 1.0)],
#  'down<END> what about down': [('ido', 1.0)],
#  'yes doctor<END> did he': [('say', 1.0)],
#  'learning where does he': [('sell', 1.0)],
#  'she is in the': [('bathroom<END>', 1.0)],
#  'which parts<END> cool pictures': [('you', 1.0)],
#  'turn around<END> tell me': [('i', 1.0)],
#  'i want his name<END>': [('stop', 1.0)],
#  'mr president it cannot<END>': [('what', 1.0)],
#  'you mind not at': [('all<END>', 1.0)],
#  'down stay down bobby<END>': [('how', 1.0)],
#  'sluggish like a wet': [('sponge', 0.5), ('sponge<END>', 0.5)],
#  'id<END> sorrypd only it': [('is', 1.0)],
#  'cell survived<END> actually only': [('one', 1.0)],
#  'pardon it was a': [('wolf<END>', 1.0)],
#  'good as a plumber<END>': [('as', 1.0)],
#  'chacha hamas uhyou are': [('welcome<END>', 1.0)],
#  'is david acting strangely<END>': [('is', 1.0)],
#  'becoming a prostitute yes': [('i', 1.0)],
#  'oh miss price yes': [('doctor<END>', 1.0)],
#  'sister the mewling rampalian': [('wretch', 1.0)],
#  'take a picture<END> you': [('do', 1.0)],
#  'you named it already<END>': [('they', 1.0)],
#  'is david acting strangely': [('no', 1.0)],
#  'we spent it ha': [('ha<END>', 1.0)],
#  'he<END> hard man to': [('live', 1.0)],
#  'yes yes come with': [('me<END>', 1.0)],
#  'did you do it': [('why', 1.0)],
#  'that is unique not': [('what', 1.0)],
#  'you know i know<END>': [('i', 1.0)],
#  'with me no way<END>': [('what', 1.0)],
#  'is good who<END> good': [('who', 1.0)],
#  "the devil's child we": [('will', 1.0)],
#  'poisoned his life but': [('not', 1.0)],
#  'how did you manage': [('it<END>', 1.0)],
#  'guess<END> you think oh': [('yeah<END>', 1.0)],
#  'are you feeling fernando': [('not', 1.0)],
#  'world<END> i am not': [('going', 1.0)],
#  'itdown below radiation levelconstantly': [('rising<END>', 1.0)],
#  'ha ha<END> a job': [('yes', 1.0)],
#  'i am sure<END> all': [('right', 1.0)],
#  'sleep<END> what about margie': [('what', 1.0)],
#  'i dream of death': [('mostly<END>', 1.0)],
#  'right just a sec<END>': [('that', 1.0)],
#  'ahead you have great': [('tits<END>', 1.0)],
#  'she okay i hope': [('so<END>', 1.0)],
#  'works pretty good thank': [('you<END>', 1.0)],
#  'are polish my folks': [('are<END>', 1.0)],
#  'you believe in it<END>': [('confutatis', 1.0)],
#  'this will work no': [('fear<END>', 1.0)],
#  'what difference does that': [('make<END>', 1.0)],
#  'if they udou i': [('do', 1.0)],
#  'is stupid why people': [('fart', 1.0)],
#  'english you said speak': [('czech<END>', 1.0)],
#  'how would you know<END>': [('keep', 1.0)],
#  'is a secret<END> yes': [('thank', 1.0)],
#  'hearing only i think': [('so', 1.0)],
#  'say anything where are': [('we', 1.0)],
#  'manager<END> yeah i know': [('the', 1.0)],
#  'i interrupting something not': [('at', 1.0)],
#  'the assistant manager<END> yeah': [('i', 1.0)],
#  'a policeman<END> i want': [('to', 1.0)],
#  'my heart mozart<END> with': [('all', 1.0)],
#  'oh excellency would you': [('with', 1.0)],
#  'i guess<END> you think': [('oh', 1.0)],
#  'chub says you are': [('fired<END>', 1.0)],
#  'heard the news i': [('hear', 1.0)],
#  'bedroom there is only': [('one', 1.0)],
#  'give it back try': [('and', 1.0)],
#  'it hurts aw jesus': [('lay', 1.0)],
#  'it is my wife': [('i', 1.0)],
#  'brothel<END> what does he': [('look', 1.0)],
#  'is all that survived': [('actually', 1.0)],
#  'about i dream of': [('death', 1.0)],
#  'are you i brought': [('the', 1.0)],
#  'yeah i mean that<END>': [('call', 1.0)],
#  'you making any headway': [('she', 1.0)],
#  'he work in there': [('sir<END>', 1.0)],
#  'david acting strangely no': [('not', 1.0)],
#  'right can we dream<END>': [('how', 1.0)],
#  'the running time thirtyfour': [('seconds<END>', 1.0)],
#  'lots see get your': [('boots<END>', 1.0)],
#  'was that korfin<END> tomorrow': [('at', 1.0)],
#  'belongs to pop<END> i': [('want', 1.0)],
#  'have you been nowhere': [('hi', 1.0)],
#  'not leaving you i': [('am', 1.0)],
#  'she is fine<END> see': [('you', 1.0)],
#  "not because there's nothing": [('to', 1.0)],
#  'stay here<END> two heads': [('better', 1.0)],
#  'do you read twenty': [('eight<END>', 1.0)],
#  'no way<END> what about': [('luther', 1.0)],
#  'save the world<END> i': [('am', 1.0)],
#  'that is that<END> that': [('is', 1.0)],
#  'love you<END> and a': [('little', 1.0)],
#  'lies colon do not<END>': [('i', 1.0)],
#  'what good stuff the': [('real', 1.0)],
#  'common time<END> i think': [('so', 1.0)],
#  'fucked<END> would you like': [('a', 1.0)],
#  'it obvious<END> why you': [('i', 1.0)],
#  'love you<END> you could': [('not', 1.0)],
#  'we are taking off': [('let', 1.0)],
#  'love these gentlemen are': [('from', 1.0)],
#  'her belongings her belongings<END>': [('none', 1.0)],
#  'afraid not<END> oh excellency': [('would', 1.0)],
#  'no no it is': [('him<END>', 1.0)],
#  'it should i<END> i': [('did', 1.0)],
#  'would you<END> get out': [('how', 1.0)],
#  'yeah i have been': [('busy<END>', 1.0)],
#  'am camera shy<END> where': [('is', 1.0)],
#  'could not you do': [('not', 1.0)],
#  'right here<END> what are': [('you', 1.0)],
#  'a wolf<END> aw come': [('on', 1.0)],
#  'aw come on miss': [('price', 1.0)],
#  'hi it is me': [('fuck', 1.0)],
#  'you laughing about napoleon': [('small<END>', 1.0)],
#  'tom alright tom<END> i': [('figured', 1.0)],
#  'go love you me': [('too<END>', 1.0)],
#  'we going i am': [('coming', 1.0)],
#  "there's no way hear": [('me', 1.0)],
#  'my baby<END> my baby': [('what', 1.0)],
#  'ballet ballet what ballet<END>': [('bravo', 1.0)],
#  'will be i will': [('be', 1.0)],
#  'you like a drink': [('no', 1.0)],
#  'are right there you': [('go', 1.0)],
#  'okay i was not': [('sure<END>', 1.0)],
#  'not tired yet<END> pay': [('money', 1.0)],
#  'what sort you are': [('a', 1.0)],
#  'no are you proposing<END>': [('hi', 1.0)],
#  "'bye 'bye now sweetheart": [('goodbye', 1.0)],
#  'might not kill it': [('you', 1.0)],
#  'flying objects thenthis is': [('a', 1.0)],
#  'it hurt<END> why not': [('put', 1.0)],
#  'is<END> how do i': [('look', 1.0)],
#  'it which parts<END> cool': [('pictures', 1.0)],
#  'thank you<END> thank you': [('do', 0.5), ('want', 0.5)],
#  'said speak czech how': [('you', 1.0)],
#  'you would new worlds': [('create', 1.0)],
#  'zorg i know<END> who': [('are', 1.0)],
#  'dr neilsen he will': [('be<END>', 1.0)],
#  'he always look so': [('block', 1.0)],
#  'i am not smoking': [('your', 1.0)],
#  'stop talking you got': [('absolute', 1.0)],
#  'to die<END> yes a': [('little', 1.0)],
#  'is carrying a bomb<END>': [('he', 1.0)],
#  'i know who it': [('is', 0.5), ('is<END>', 0.5)],
#  'are a monster zorg': [('i', 1.0)],
#  'you mean that is': [('right', 1.0)],
#  'you set me up<END>': [('you', 1.0)],
#  'i mean that<END> call': [('me', 1.0)],
#  'him<END> you think jack': [('shot', 1.0)],
#  'friday then oh right': [('friday<END>', 1.0)],
#  'will work no fear<END>': [('what', 1.0)],
#  'of my favorites you': [('made', 1.0)],
#  'me i love you<END>': [('the', 1.0)],
#  'yes when may i': [('ask<END>', 1.0)],
#  'what time common time<END>': [('i', 1.0)],
#  'it<END> who is he': [('todd', 1.0)],
#  'you played for the': [('sox', 0.5), ('sox<END>', 0.5)],
#  'be disappointed<END> do not': [('bother', 1.0)],
#  'a large asteroid<END> shut': [('down', 1.0)],
#  'i am afraid not<END>': [('oh', 1.0)],
#  'wrong with that<END> great': [('place', 1.0)],
#  "sixteen 'c' why<END> sixteen": [("'c'", 1.0)],
#  'am sick<END> what does': [('she', 1.0)],
#  'coming with you<END> i': [('am', 1.0)],
#  'what is what<END> here': [('in', 1.0)],
#  'it is okay dan<END>': [('hi', 1.0)],
#  'czech girl<END> speak english': [('you', 1.0)],
#  'know this<END> ah you': [('have', 1.0)],
#  'you were divorced<END> valo': [('massa', 1.0)],
#  'you think chief<END> yeah': [('right', 1.0)],
#  'what are you doing': [('flying', 0.3333333333333333),
#   ('pouring', 0.3333333333333333),
#   ('here', 0.3333333333333333)],
#  'it belongs to pop<END>': [('i', 1.0)],
#  'good thank you<END> thank': [('you', 1.0)],
#  'the dead what dead': [('who', 1.0)],
#  'chest<END> in the chest': [('no', 1.0)],
#  'help<END> what is it': [('oh', 1.0)],
#  'did he say a': [('wolf', 1.0)],
#  'yeah i guess get': [('some', 1.0)],
#  'uramu him<END> he did': [('i', 1.0)],
#  'not be late<END> you': [('brought', 1.0)],
#  'that make<END> are you': [('absolutely', 1.0)],
#  'he is not<END> no': [('you', 1.0)],
#  'me too<END> that is': [('right', 1.0)],
#  'think chief<END> yeah right': [('what', 1.0)],
#  'the hell happened<END> hi': [('frank', 1.0)],
#  'hirsch go about your': [('duties<END>', 1.0)],
#  'oh thank you very': [('much', 1.0)],
#  'us dear it is': [('okay', 1.0)],
#  "seventeen meters let's get": [('these', 1.0)],
#  'he is my collar': [('well', 1.0)],
#  'i ask in three': [('months', 1.0)],
#  'calling mrs christian<END> anything': [('harder', 1.0)],
#  'fine fine<END> you and': [('mel', 1.0)],
#  'doing<END> how is she': [('doing', 1.0)],
#  'kitchen very nice<END> the': [('bedroom', 1.0)],
#  'not his body what': [('difference', 1.0)],
#  'is<END> sothe station is': [('empty', 1.0)],
#  'i said<END> that is': [('what', 1.0)],
#  "salucci sixteen 'c' why<END>": [('sixteen', 1.0)],
#  'will be right back<END>': [('no', 1.0)],
#  'all wet that is': [('wrong', 1.0)],
#  'to go home okay': [("let's", 1.0)],
#  'are learning<END> you are': [('learning', 1.0)],
#  'was me<END> you might': [('not', 1.0)],
#  'skipper right at our': [('oneeyed', 1.0)],
#  'there it is<END> your': [('majesty', 1.0)],
#  'what you did<END> i': [('know', 1.0)],
#  'what kind<END> it hurts': [('aw', 1.0)],
#  'guy so they tell': [('me<END>', 1.0)],
#  'sox double a new': [('britain<END>', 1.0)],
#  'we going<END> where are': [('we', 1.0)],
#  'cannot it wait no': [('mr', 1.0)],
#  'you want<END> what do': [('you', 1.0)],
#  'acting the way we': [('do<END>', 1.0)],
#  'is him<END> the man': [('he', 1.0)],
#  'sungs gettin high deers': [('have', 1.0)],
#  'oneeyed friend<END> sidearms but': [('the', 1.0)],
#  'me<END> excuse me the': [('fax', 1.0)],
#  'here<END> now or he': [('dies', 1.0)],
#  'i am just aces<END>': [("who's", 1.0)],
#  'am a werewolf a': [('werewolf<END>', 1.0)],
#  'you absolutely sure i': [('have', 1.0)],
#  'good time<END> must be': [("billy's", 1.0)],
#  'favorites<END> yeah one of': [('my', 1.0)],
#  'backwards<END> oh ha ha': [('ha', 1.0)],
#  'better perfect mr president<END>': [('smoking', 1.0)],
#  'missed it<END> you are': [('polish', 1.0)],
#  'busy sir i understand<END>': [('what', 1.0)],
#  'only one cell survived': [('have', 1.0)],
#  'cannot stand it what': [('is', 1.0)],
#  'it is harcourt<END> it': [('is', 1.0)],
#  'under attack where is': [('my', 1.0)],
#  'going why not<END> it': [('is', 1.0)],
#  'is a miracle what': [('is<END>', 1.0)],
#  'up does it hurt<END>': [('why', 1.0)],
#  'people fart backwards<END> oh': [('ha', 1.0)],
#  'survived have you identified': [('it<END>', 1.0)],
#  'ttthanks alice earth to': [('alice<END>', 1.0)],
#  'like it then how': [('could', 1.0)],
#  'work in there sir<END>': [('are', 1.0)],
#  'polish my folks are<END>': [('my', 1.0)],
#  'was it not good<END>': [('get', 1.0)],
#  'is this herr chamberlain': [('what', 1.0)],
#  'you would<END> i knew': [('you', 1.0)],
#  'harcourt<END> it is harcourt': [('harcourt', 1.0)],
#  'yourself together not yet<END>': [('6', 1.0)],
#  'no you did not': [('i', 1.0)],
#  'is pretty old it': [('belongs', 1.0)],
#  'know i know<END> i': [('know', 1.0)],
#  'a wolf yes i': [('believe', 1.0)],
#  'mewling rampalian wretch herself<END>': [('her', 1.0)],
#  'wait well promise then<END>': [('well', 1.0)],
#  'hurt<END> why not put': [('the', 1.0)],
#  'does not look like': [('it<END>', 1.0)],
#  'eva condition<END> this is': [('three', 1.0)],
#  'who did cause and': [('origin', 1.0)],
#  'room report<END> that is': [('the', 1.0)],
#  'did dan<END> mark are': [('you', 1.0)],
#  'around please<END> unidentified flying': [('objects', 1.0)],
#  'speedabout twentytwo knots coursedue': [('north<END>', 1.0)],
#  'speed speedabout twentytwo knots': [('coursedue', 1.0)],
#  'the girl<END> hey do': [('you', 1.0)],
#  'are a policeman<END> i': [('want', 1.0)],
#  'daddy daddy please jim': [('for', 1.0)],
#  'twentyseven i know<END> shall': [('i', 1.0)],
#  'likely convict<END> you stay': [('with', 1.0)],
#  'that is illegal you': [('know', 1.0)],
#  'alex<END> what do you': [('dream', 1.0)],
#  'you think jack shot': [('him<END>', 0.5), ('him', 0.5)],
#  'uncle dead at fortyone<END>': [('he', 1.0)],
#  'what course skipper right': [('at', 1.0)],
#  'shot him well it': [('was', 1.0)],
#  'reading i was reading': [('too<END>', 1.0)],
#  'get us maybe maybe': [('not<END>', 1.0)],
#  'the story<END> kruger sagittarius': [('commissioner', 1.0)],
#  'be late<END> you brought': [('the', 1.0)],
#  'got it stay cool<END>': [('that', 1.0)],
#  'one i heard voices<END>': [('i', 1.0)],
#  'where is my family<END>': [('where', 1.0)],
#  'so show me<END> you': [('go', 1.0)],
#  'you saw him too<END>': [('it', 1.0)],
#  'are under attack<END> we': [('are', 1.0)],
#  'are you take out': [('your', 1.0)],
#  'you did who is': [('this<END>', 1.0)],
#  'accident<END> the night before': [('the', 1.0)],
#  'all<END> a hundred bucks': [('a', 1.0)],
#  'be better<END> why not': [('it', 1.0)],
#  'new worlds create new': [('people<END>', 1.0)],
#  'better dad you<END> you': [('read', 1.0)],
#  'what on one hearing': [('only', 1.0)],
#  'attack<END> we are under': [('attack', 1.0)],
#  'nothing to see<END> dear': [('mozart', 1.0)],
#  'many people go here<END>': [('that', 1.0)],
#  'time phone ahead how': [('is', 1.0)],
#  'see get your boots': [('hi', 1.0)],
#  'girl remember<END> i brought': [('the', 1.0)],
#  'love you<END> the cash': [('man', 1.0)],
#  'my folks are<END> my': [('folks', 1.0)],
#  'good hey you guys': [('back', 1.0)],
#  'dollars is it<END> that': [('is', 1.0)],
#  'stupid why people fart': [('backwards<END>', 1.0)],
#  'poached not over over<END>': [('which', 1.0)],
#  'wake up wah where': [('are<END>', 1.0)],
#  'time thirtyfour seconds<END> right': [('uatu', 1.0)],
#  'what is this<END> why': [('not', 1.0)],
#  'are you doing this': [('i', 1.0)],
#  'oh god he killed': [('them<END>', 1.0)],
#  'vito cor nilious priest': [('vito', 1.0)],
#  'information we do<END> yeah': [("who's", 1.0)],
#  'they udou i do': [('not', 1.0)],
#  'a private investigator that': [('is', 1.0)],
#  'religious<END> what is this': [('those', 1.0)],
#  'is stupid it is': [('fun<END>', 1.0)],
#  'are taking off let': [('me', 1.0)],
#  'i not<END> whom did': [('they', 1.0)],
#  'and that fits<END> why': [('did', 1.0)],
#  'taking a bath any': [('id<END>', 1.0)],
#  'a drink no thank': [('you<END>', 1.0)],
#  'that is he looking': [('for', 1.0)],
#  'one<END> no one i': [('heard', 1.0)],
#  'kurtz i presume<END> cannot': [('you', 1.0)],
#  'stupid<END> yeah it is': [('stupid', 1.0)],
#  'i am not leaving': [('you', 1.0)],
#  'for you i never': [('killed', 1.0)],
#  'right premature ejection<END> i': [('think', 1.0)],
#  'okay<END> watch the news': [('nah', 1.0)],
#  'you guys back already<END>': [('how', 1.0)],
#  "am just aces<END> who's": [('jacob', 1.0)],
#  'on duty<END> why not': [('something', 1.0)],
#  'i cannot stand it': [('what', 1.0)],
#  'which one all 900<END>': [('you', 1.0)],
#  "just aces<END> who's jacob": [('my', 1.0)],
#  'ya doing cannot complain<END>': [('let', 1.0)],
#  'jesus lay down stay': [('down', 1.0)],
#  'am not telling you': [('why', 1.0)],
#  'grazie mio caro wolfgang': [('grazie', 1.0)],
#  'on he is busy': [('being', 1.0)],
#  'that sorry babe<END> you': [('are', 1.0)],
#  'never been proven neither': [('has', 1.0)],
#  'boots hi honey<END> did': [('you', 1.0)],
#  'so sing it back<END>': [('with', 1.0)],
#  'we accomplish we can': [('uramu', 1.0)],
#  'enlighten me<END> big date': [('tonight', 1.0)],
#  'you set me up': [('i', 1.0)],
#  'fine<END> see you tomorrow': [('maybe', 1.0)],
#  'you what oh yes': [('please<END>', 1.0)],
#  'in the bathroom<END> yes': [('daddy', 1.0)],
#  'than one<END> you thirsty': [('i', 1.0)],
#  'miss price call me': [('alex<END>', 1.0)],
#  'too ambitious<END> you defend': [('yourself', 1.0)],
#  'the sox<END> you played': [('for', 1.0)],
#  'money is good<END> yes': [('the', 1.0)],
#  'and hope to die<END>': [('yes', 1.0)],
#  'so ashamed what for<END>': [('what', 1.0)],
#  'neither has his heterosexuality<END>': [('you', 1.0)],
#  'not ask questions fuck': [('you<END>', 1.0)],
#  'you are killing me': [('do', 1.0)],
#  'i love you i': [('love', 1.0)],
#  'twentytwo knots coursedue north<END>': [('what', 1.0)],
#  'way<END> you considered becoming': [('a', 1.0)],
#  'no it is him<END>': [('the', 1.0)],
#  'appointment to what<END> appointment': [('to', 1.0)],
#  'is this an attempted': [('slit<END>', 1.0)],
#  'you<END> you read my': [('mind', 1.0)],
#  'please<END> unidentified flying objects': [('thenthis', 1.0)],
#  'did she die is': [('she', 1.0)],
#  'did<END> no why is': [('david', 1.0)],
#  "am i<END> sowho's nicky": [('what', 1.0)],
#  'would<END> i knew you': [('would', 1.0)],
#  'where are we going': [('to', 0.5), ('i', 0.5)],
#  ...}
